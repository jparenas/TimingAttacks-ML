# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

import pandas as pd
import numpy as np
from sklearn import manifold, neighbors, linear_model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt

import lightgbm as lgb

# %%
df = pd.read_csv('../data/train_v2.csv')
df.head()
# Out:
#                                                 text  length      time algo
# 0  1OOCAVJD4SD0MQB79HFQFJXRYYPF7CY1IMBERXIRGA6COK...     100  0.005665  MD5
# 1  QAN7ZGJ5YR9HYZJESTVM3W0FAZF834GLDQKFCS5AEHRRVH...    1000  0.003275  MD5
# 2  AER4LGOMEW4VR4WQENX3N1DS31WO8MZFU6XQFVXRW0WUYW...     100  0.003224  MD5
# 3  15HWFB0RYW73BAUUNQPJ8YX057NVO64M7PFIDNLB6WZKRA...    1000  0.003350  MD5
# 4                   QVSB8FK4PJ712MQBZLVEZX0CBXLSOHF7      32  0.003167  MD5

# %%
df['algo'].value_counts()
# Out:
# MD5       20000
# SHA512    20000
# SHA256    20000
# Name: algo, dtype: int64

# %%
df.groupby(['algo']).mean()
# Out:
#           length      time
# algo
# MD5     293.4400  0.004112
# SHA256  294.4076  0.004072
# SHA512  288.1184  0.003967

# %%
df.boxplot('time', by=['algo'], showfliers=False)

# %%
df.boxplot('time', by=['algo'])

# %%
colors = df['algo'].map({'MD5': 'red', 'SHA256': 'blue', 'SHA512': 'green'})
colors
# Out:
# 0          red
# 1          red
# 2          red
# 3          red
# 4          red
# 5          red
# 6          red
# 7          red
# 8          red
# 9          red
# 10         red
# 11         red
# 12         red
# 13         red
# 14         red
# 15         red
# 16         red
# 17         red
# 18         red
# 19         red
# 20         red
# 21         red
# 22         red
# 23         red
# 24         red
# 25         red
# 26         red
# 27         red
# 28         red
# 29         red
#          ...
# 59970    green
# 59971    green
# 59972    green
# 59973    green
# 59974    green
# 59975    green
# 59976    green
# 59977    green
# 59978    green
# 59979    green
# 59980    green
# 59981    green
# 59982    green
# 59983    green
# 59984    green
# 59985    green
# 59986    green
# 59987    green
# 59988    green
# 59989    green
# 59990    green
# 59991    green
# 59992    green
# 59993    green
# 59994    green
# 59995    green
# 59996    green
# 59997    green
# 59998    green
# 59999    green
# Name: algo, Length: 60000, dtype: object

# %%
plt.scatter(df['length'], df['time'], c=colors, alpha=0.2)
plt.show()

# %%
sizes = [10, 32, 100, 320, 1000]
algos = ['MD5', 'SHA256', 'SHA512']

f, ax = plt.subplots(3, 2, figsize=(20, 10))

for i, size in enumerate(sizes):
    ax[i // 2, i % 2].boxplot(
        [df[(df['length'] == size) & (df['algo'] == algo)]['time'] for algo in algos],
        #showfliers=False
    )
    ax[i // 2, i % 2].set_title(f'Size: {size}')
    ax[i // 2, i % 2].set(xticklabels=algos)

plt.show()

# %%
sizes = [10, 32, 100, 320, 1000]
algos = ['MD5', 'SHA256', 'SHA512']

f, ax = plt.subplots(3, 2, figsize=(20, 10))

for i, size in enumerate(sizes):
    ax[i // 2, i % 2].boxplot(
        [df[(df['length'] == size) & (df['algo'] == algo)]['time'] for algo in algos],
        showfliers=False
    )
    ax[i // 2, i % 2].set_title(f'Size: {size}')
    ax[i // 2, i % 2].set(xticklabels=algos)

plt.show()

# %% [markdown]
# ## Generating mean + stdev data

# %%
new_df = df[['length', 'time', 'algo']]
new_df.head()
# Out:
#    length      time algo
# 0     100  0.005665  MD5
# 1    1000  0.003275  MD5
# 2     100  0.003224  MD5
# 3    1000  0.003350  MD5
# 4      32  0.003167  MD5

# %%
new_df['time_mean'] = 0
new_df['time_stdev'] = 0
new_df.head()
# Out:
#    length      time algo  time_mean  time_stdev
# 0     100  0.005665  MD5          0           0
# 1    1000  0.003275  MD5          0           0
# 2     100  0.003224  MD5          0           0
# 3    1000  0.003350  MD5          0           0
# 4      32  0.003167  MD5          0           0

# %%
print(new_df.shape)
# Out:
# (60000, 5)

# %%
def get_stats(row, pop_size=300):
    pop = new_df[(new_df['algo'] == row['algo']) & (new_df['length'] == row['length'])].sample(pop_size - 1)
    #print(pop.shape)
    #print(pop.head())
    
    pop = pop.append(row)
    #print(pop.shape)
    #print(pop.head())
    
    #row.at['time_mean'] = pop['time'].mean()
    #row.at['time_stdev'] = pop['time'].std()
    
    #return row
    return pop['time'].mean(), pop['time'].std()

# %%
"""
means = []
stds = []

#for i in range(new_df.shape[0]):
for i, row in new_df.iterrows():
#for i in range(100):
    #row = new_df.iloc[i]
    
    mean, std = get_stats(row, pop_size=10)
    means.append(mean)
    stds.append(std)
    
    #new_df.iloc[i] = get_stats(row, pop_size=10)
    
new_df['time_mean'] = means
new_df['time_std'] = stds
"""
#new_df = new_df.sample(1000)

new_df[['time_mean', 'time_stdev']] = new_df.apply(get_stats, axis=1, result_type='expand')
print(new_df.shape)
new_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-bcdf2841de41> in <module>
#      19 #new_df = new_df.sample(1000)
#      20
# ---> 21 new_df[['time_mean', 'time_stdev']] = new_df.apply(get_stats, axis=1, result_type='expand')
#      22 print(new_df.shape)
#      23 new_df.head()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# /usr/local/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-16-c581654cc5bb> in get_stats(row, pop_size)
#       1 def get_stats(row, pop_size=300):
# ----> 2     pop = new_df[(new_df['algo'] == row['algo']) & (new_df['length'] == row['length'])].sample(pop_size - 1)
#       3     #print(pop.shape)
#       4     #print(pop.head())
#       5
#
# /usr/local/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1281
#    1282             with np.errstate(all='ignore'):
# -> 1283                 res = na_op(values, other)
#    1284             if is_scalar(res):
#    1285                 raise TypeError('Could not compare {typ} type with Series'
#
# /usr/local/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1141
#    1142         elif is_object_dtype(x.dtype):
# -> 1143             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1144
#    1145         elif is_datetimelike_v_numeric(x, y):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1120         result = libops.vec_compare(x, y, op)
#    1121     else:
# -> 1122         result = libops.scalar_compare(x, y, op)
#    1123     return result
#    1124
#
# KeyboardInterrupt:

# %%
# TODO: move 'algo' to last column, write to CSV
new_df = new_df[['length', 'time', 'time_mean', 'time_stdev', 'algo']]
new_df.head()
# Out:
#    length      time  time_mean  time_stdev algo
# 0     100  0.005665   0.003833    0.001759  MD5
# 1    1000  0.003275   0.003902    0.001815  MD5
# 2     100  0.003224   0.004150    0.003057  MD5
# 3    1000  0.003350   0.003867    0.002102  MD5
# 4      32  0.003167   0.004285    0.003479  MD5

# %%
new_df.to_csv('data/stats_train_v2.csv', index=False)

# %%
df = pd.read_csv('../data/stats_train_v2.csv')
print(df.shape)
df.head()
# Out:
# (60000, 5)
#    length      time  time_mean  time_stdev algo
# 0     100  0.005665   0.003833    0.001759  MD5
# 1    1000  0.003275   0.003902    0.001815  MD5
# 2     100  0.003224   0.004150    0.003057  MD5
# 3    1000  0.003350   0.003867    0.002102  MD5
# 4      32  0.003167   0.004285    0.003479  MD5

# %%
#df = df.sample(5000).reset_index()
X, y = df, df.pop('algo')

# %%
print(X.head())
print(y.head())
# Out:
#    length      time  time_mean  time_stdev
# 0     100  0.005665   0.003833    0.001759
# 1    1000  0.003275   0.003902    0.001815
# 2     100  0.003224   0.004150    0.003057
# 3    1000  0.003350   0.003867    0.002102
# 4      32  0.003167   0.004285    0.003479
# 0    MD5
# 1    MD5
# 2    MD5
# 3    MD5
# 4    MD5
# Name: algo, dtype: object

# %%
perplexity = 
tsne = manifold.TSNE(init='random',
                     random_state=0, perplexity=perplexity,
                     n_iter=5000)
Y = tsne.fit_transform(X)

# %%
algos = {'MD5': 'red', 'SHA256': 'blue', 'SHA512': 'green'}

for algo, color in algos.items():
    indices = y.index[y == algo]
    plt.scatter(Y[indices, 0], Y[indices, 1], c=color, marker='.', label=algo)

plt.legend()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(
                X, y, test_size=0.15)

# %%
n_neighbors = 15
knn = neighbors.KNeighborsClassifier(n_neighbors)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

acc = accuracy_score(y_test, y_pred)
print(f'Accuracy: {acc * 100}%')
# Out:
# Accuracy: 65.34444444444445%

# %%
sgd = linear_model.SGDClassifier(max_iter=3000, tol=1e-4)
sgd.fit(X_train, y_train)

y_pred = sgd.predict(X_test)

acc = accuracy_score(y_test, y_pred)
print(f'Accuracy: {acc * 100}%')
# Out:
# Accuracy: 33.900000000000006%

# %%
rndf = RandomForestClassifier(n_estimators=100)
rndf.fit(X_train, y_train)

y_pred = rndf.predict(X_test)

acc = accuracy_score(y_test, y_pred)
print(f'Accuracy: {acc * 100}%')
# Out:
# Accuracy: 66.5%

# %%
coef = pd.Series(rndf.feature_importances_, index = X.columns)
imp_coef = coef.sort_values()
imp_coef.plot(kind = "bar")
plt.title("Feature importance using Random Forest")
# Out:
# Text(0.5, 1.0, 'Feature importance using Random Forest')
